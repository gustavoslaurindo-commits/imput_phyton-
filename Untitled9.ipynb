# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoslaurindo-commits/imput_phyton-/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def mensagem(nome):
    print(f"bom dia, {nome}")

mensagem("Ana")
mensagem("josé")
# Out:
# bom dia, Ana
# bom dia, josé

# %%
def apresentar(nome,idade):
  print(f"{nome} tem {idade} anos")
  apresentar ("Carlos", 31)
  apresentar("Ana", 25)

# %%
## parametro com valor padrao
def saudacao(nome,periodo="dia"):
  print(f"Bom{periodo}, {nome}")
  saudacao("ana")
  saudacao ("josé","noite")

# %%
def somar(a,b):
 resultado = a+b
 return resultado
 i
 print(somar(10,20))

# %%
def eh_par(numero):
    return numero % 2 == 0

print(eh_par(4))

numero = int(imput("Digite um numero: "))
if eh_par(num)
print(eh_par)
else: eh_impar
print(eh_impar)
# Out:
# True

# %%
def calcula_media(notas):
  for nota in notas:
    soma = soma = nota
    return soma / len(notas)
    notas_A = [7,8,6]
    notas_b = [5,9,5]
    print(f"{calcula_media(notas_A):.2f}")
    print(f"{calcula_media(notas_B):.2f}")

# %%
## validador de dados
def maior_de_idade(idade):
    return idade >= 18

idade = int(input("digite sua idade: "))

if maior_de_idade(idade):
    print("acesso permitido")
else:
    print("acesso negado")
# Out:
# digite sua idade: 18
# acesso permitido

# %%
## calculadora de desconto
def calcular(preco, desconto_percentual):
    desconto = preco * (desconto_percentual / 100)
    return preco - desconto

produto = float(input("digite o valor do produto: "))
desc = float(input("digite o valor do desconto: "))

preco_final = calcular(produto, desc)
print(f"preco final R${preco_final:.2f}")
# Out:
# digite o valor do produto: 65
# digite o valor do desconto: 10
# preco final R$58.50
