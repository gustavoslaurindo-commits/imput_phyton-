# %%
   ######## Atividade dos desafios
## lista
projetos = ["ERP Corporativo", "App Financeiro", "Portal do Cliente", "Sistema de Estoque", "Dashboard BI"]
# 1. Acesse e mostre o primeiro projeto (índice)

print(projetos[0])


   # 2. Adicione "API de Integração"
projetos.append("API de Integração")
print(projetos)



# 3. Remover "Sistema de Estoque"
projetos.remove("Sistema de Estoque")
print(projetos)



### 4 Remova o projeto da posição 1
projetos.pop(1)
print(projetos)



######### 5  Altere "Dashboard BI" para "Dashboard Analytics
projetos[3] = "Dashboard Analitics"
print(projetos)



### 6 mostrar a quantidade de projetos
print(len(projetos))



# 7. Organizar em ordem alfabética
projetos.sort()
print(projetos)



# 8. Inverta a ordem
projetos.reverse()
print(projetos)



# 9. Verificar se "ERP Corporativo" está na lista

projetos = ["ERP Corporativo", "App Financeiro", "Portal do Cliente", "Sistema de Estoque", "Dashboard BI"]
print("ERP Corporativo" in projetos)




# 10. Lista final
print( projetos)
# Out:
# ERP Corporativo
# ['ERP Corporativo', 'App Financeiro', 'Portal do Cliente', 'Sistema de Estoque', 'Dashboard BI', 'API de Integração']
# ['ERP Corporativo', 'App Financeiro', 'Portal do Cliente', 'Dashboard BI', 'API de Integração']
# ['ERP Corporativo', 'Portal do Cliente', 'Dashboard BI', 'API de Integração']
# ['ERP Corporativo', 'Portal do Cliente', 'Dashboard BI', 'Dashboard Analitics']
# 4
# ['Dashboard Analitics', 'Dashboard BI', 'ERP Corporativo', 'Portal do Cliente']
# ['Portal do Cliente', 'ERP Corporativo', 'Dashboard BI', 'Dashboard Analitics']
# True
# ['ERP Corporativo', 'App Financeiro', 'Portal do Cliente', 'Sistema de Estoque', 'Dashboard BI']
