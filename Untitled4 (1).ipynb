# %%
senha_correta = "senai2026"

senha = input("Digite sua senha: ")
if senha ==  senha_correta:
  print("acesso permitido")
else:
  print("Acesso negado")
# Out:
# Digite sua senha: senai2025
# Acesso negado

# %%
senha_correta = "senai2026"

senha = input("Digite sua senha: ")
if senha ==  senha_correta:
  print("acesso permitido")
else:
  print("Acesso negado")
# Out:
# Digite sua senha: senai2026
# acesso permitido
