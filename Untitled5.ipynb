# %%
 #atvidade sobre meta


meta = int(input("Digite sua meta: "))
if meta == 8000:
  print("Meta alcançada")
else:
    print("meta nao alcançada")
# Out:
# Digite sua meta: 8000
# Meta alcançada

# %%
meta = int(input("Digite sua meta: "))
if meta == 8000:
  print("Meta alcançada")
else:
    print("meta nao alcançada")
# Out:
# Digite sua meta: 67
# meta nao alcançada
