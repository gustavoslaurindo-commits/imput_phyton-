# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoslaurindo-commits/imput_phyton-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # notas do aluno
nota = float(input("Digite sua nota:"))

if nota >= 9:
    print("Aprovado com excelência")
elif nota >= 7:
    print("Aprovado congratulations")
elif nota >= 5 and nota <= 6.99:
    print("Você ficou de recuperação")
else:
    print("Reprovado")
# Out:
# Digite sua nota:10
# Aprovado com excelência

# %%
nota = float(input("Digite sua nota:"))

if nota >= 9:
    print("Aprovado com excelência")
elif nota >= 7:
    print("Aprovado congratulations")
elif nota >= 5 and nota <= 6.99:
    print("Você ficou de recuperação")
else:
    print("Reprovado")
# Out:
# Digite sua nota:7
# Aprovado congratulations

# %%
nota = float(input("Digite sua nota:"))

if nota >= 9:
    print("Aprovado com excelência")
elif nota >= 7:
    print("Aprovado congratulations")
elif nota >= 5 and nota <= 6.99:
    print("Você ficou de recuperação")
else:
    print("Reprovado")
# Out:
# Digite sua nota:6.7
# Você ficou de recuperação

# %%
nota = float(input("Digite sua nota:"))

if nota >= 9:
    print("Aprovado com excelência")
elif nota >= 7:
    print("Aprovado congratulations")
elif nota >= 5 and nota <= 6.99:
    print("Você ficou de recuperação")
else:
    print("Reprovado")
# Out:
# Digite sua nota:4.9
# Reprovado

# %%
  #versão simples

nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
ingresso = input("Você possui ingresso? (sim/não): ")

if idade >= 18 and ingresso == "sim":
    print("Entrada permitida!")

else:
    print("Entrada não permitida.")
# Out:
# Digite seu nome: gustavo
# Digite sua idade: 17
# Você possui ingresso? (sim/não): sim
# Entrada não permitida.

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
ingresso = input("Você possui ingresso? (sim/não): ")

if idade >= 18 and ingresso == "sim":
    print("Nome:", nome)
    print("Idade:", idade)
    print("Entrada permitida!")
else:
    print("Nome:", nome)
    print("Idade:", idade)
    print("Entrada não permitida.")
# Out:
# Digite seu nome: lucas
# Digite sua idade: 22
# Você possui ingresso? (sim/não): sim
# Nome: lucas
# Idade: 22
# Entrada permitida!

# %%
#atividade deconto com cartão

valor = float(input("Digite o valor da compra: "))
cartao = input("Possui cartão? (Sim/Não): ")

if valor >= 100 and cartao == "sim":
    print("Você recebeu 10% de desconto!")
else:
    print("Você não possui desconto.")
# Out:
# Digite o valor da compra: 99
# Possui cartão? (Sim/Não): sim
# Você não possui desconto.

# %%
valor = float(input("Digite o valor da compra: "))
cartao = input("Possui cartão? (Sim/Não): ")

if valor >= 100 and cartao == "sim":
    print("Você recebeu 10% de desconto!")
else:
    print("Você não possui desconto.")
# Out:
# Digite o valor da compra: 164
# Possui cartão? (Sim/Não): sim
# Você recebeu 10% de desconto!

# %%
valor = float(input("Digite o valor da compra: "))
cartao = input("Possui cartão? (Sim/Não): ")

if valor >= 100 and cartao == "sim":
    print("Você recebeu 10% de desconto!")
else:
    print("Você não possui desconto.")
# Out:
# Digite o valor da compra: 123
# Possui cartão? (Sim/Não): Não
# Você não possui desconto.
