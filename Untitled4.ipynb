# %%
#atividade 1
numero1 = int(input("Digite o primeiro número: "))
numero2 = int(input("Digite o segundo número: "))
subtração = numero1 - numero2
print("o resultado vai ser: ", subtração )
# Out:
# Digite o primeiro número: 67
# Digite o segundo número: 7
# o resultado vai ser:  60

# %%
 # atividade 2
number1 = int(input("Digite seu número: "))
number2 = int(input("Digite seu número: "))
soma = number1 + number2
print("O resultado vai ser: ", soma )
# Out:
# Digite seu número: 20
# Digite seu número: 20
# O resultado vai ser:  40

# %%
 #atv mult

number1 = int(input("Digite seu número: "))
number2 = int(input("Digite seu número: "))
multiplicação = number1 * number2
print("O resultado sera: ", multiplicação  )
# Out:
# Digite seu número: 70
# Digite seu número: 7
# O resultado sera:  490

# %%
# ATV subtração
number1 = int(input("Digite seu número: "))
number2 = int(input("Digite seu número: "))
subtracão = number1 - number2
print("O resultado sera: ", subtracão )
# Out:
# Digite seu número: 30
# Digite seu número: 29
# O resultado sera:  1

# %%
 # divisao
number1 = int(input("Digite seu número: "))
number2 = int(input("Digite seu número: "))
divisão = number1 / number2
print("O resultado sera: ", divisão )
# Out:
# Digite seu número: 490
# Digite seu número: 7
# O resultado sera:  70.0
