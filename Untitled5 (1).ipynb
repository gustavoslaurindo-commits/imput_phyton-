# %%
IDADE = int(input("Digite sua idade: "))

if IDADE < 16:
    print("Menor de idade")
elif IDADE < 18:
    print("Voto opcional")
else:
    print("Voto obrigatório")
# Out:
# Digite sua idade: 16
# Voto opcional

# %%
IDADE = int(input("Digite sua idade: "))

if IDADE < 16:
    print("Menor de idade")
elif IDADE < 18:
    print("Voto opcional")
else:
    print("Voto obrigatório")
# Out:
# Digite sua idade: 20
# Voto obrigatório
